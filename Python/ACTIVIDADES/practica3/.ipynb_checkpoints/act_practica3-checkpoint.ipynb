# %%
import os
import csv

def listarPaises(titulos):
    "Devuleve una lista con los paises sin repeticiones"
    lista_paises_xlinea = []
    for linea in titulos:
        if(linea[5].strip() != ''): 
            lista_paises_xlinea.append(linea[5].strip().split(','))
    
    lista_paises_comp = []
    for paises in lista_paises_xlinea:
        for i in paises:
            lista_paises_comp.append(i)
    lista_paises = (list(set(lista_paises_comp)))
    return(lista_paises)

 
def paisEsParte(show, lista_paises,titulos):
    ""
    print(lista_paises)
    for linea in titulos:
         if (linea[2] == show):
            for pais in lista_paises:
                if pais in linea[5]:
                    print(f"{show}, es titulo de {pais}")
                
    
    

def listarShows(linea, year):
    ""
    if int(linea[7]) == year:
        print(linea[2])

archivo_titulosnfx = "netflix_titles.csv"
carpeta_archivos = "files"

ruta_archivos = os.path.join(os.getcwd(), carpeta_archivos)


with open(os.path.join(carpeta_archivos, archivo_titulosnfx), encoding= 'utf8') as titulosnfx:
    
    reader = csv.reader(titulosnfx, delimiter = ',')
    encabezado = next(reader)
    titulos = list(reader)

    
    lista_paises = listarPaises(titulos) #1.1
    
    show = input("Ingrese un show a buscar: ")
    paisEsParte(show,lista_paises,titulos) #1.2, no funciona
    
    print(sorted(lista_paises)) #2
    
    year = int(input("Ingrese un año por favor: ")) #3
    for linea in titulos:
        listarShows(linea,year)
# Out:
# Ingrese un show a buscar: asdas
# ...
